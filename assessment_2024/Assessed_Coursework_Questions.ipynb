# %% [markdown]
# # Assessed Coursework for Data Science & Machine Learning for Geoscientists 2024
#
# ### Instructions
#
# 1. This coursework is to be completed under exam conditions. Please do not speak to other candidates during the test nor look at your classmate's computer screens.
#
# 2. You have 2 hours to complete this assessed coursework. Once you have finished, commit your changes and push those commits to your repository. **Please check that you have successfully pushed your commits - we cannot mark your work if it does not show up on the repository.**
#
# 3. We will not mark any commits pushed to your repository after **12pm on the 19th March**.
#
# 4. You are free to use the Internet during the coursework. This includes accessing repos from your previous lectures, Pandas/scikit-learn documentation, and StackOverflow. In cases where you have used the latter, please indicate that you did so and include the link to the StackOverflow question you used.
#
# 5. The use of generative AI (e.g., ChatGPT) is **NOT** allowed during this coursework.

# %% [markdown]
# # 🚀 Modelling Near Earth Objects
#
# You are a consultant in scientific machine learning, and your first client is **NASA**! They have had a lot of success with their recent **Double Asteroid Redirection Test**, or **DART** mission: now, they have an increased budget and they want to spend it on some predictive machine learning. This is where you come into play: you will help **NASA** train a machine learning algorithm that can determine whether or not a near-Earth asteroid is <font color="red">hazardous</font>.
#
# Note that **NASA** will judge you based on how clean and easy to read your code is, and how well structured your notebook is: this includes using markdown cells to explain your decisions if needed and whether you have followed the conventions of Python syntax and the best practices of data science.
#
# As you embark on the tasks in each section, remember that efficiency and organization in your data analysis and modeling processes are key to success. While not mandatory, employing pipelines can greatly enhance your workflow, allowing for more seamless integration of data preprocessing, exploratory data analysis (EDA), and model fitting.

# %% [markdown]
# ## Section 1: Loading and Splitting the Data (<font color="red">10 Marks total</font>)
#
# ### Exercise 1.1 (<font color="red">2 Marks</font>)
#
# 1. Load the training data as a Pandas dataframe: `asteroid_training.csv`. This data has the following columns:
#     - **id**: Unique Identifier for each Asteroid
#     - **name**: Name given by NASA
#     - **est_diameter**: Estimated diameter in kilometers
#     - **relative_velocity**: Velocity Relative to Earth
#     - **miss_distance**: Distance in kilometers missed
#     - **orbiting_body**: Planet that the asteroid orbits
#     - **sentry_object** Included in sentry database (an automated collision monitoring system)?
#     - **absolute_magnitude**: Describes intrinsic luminosity
#     - **hazardous**: Boolean feature that shows whether asteroid is harmful or not
# 2. Check how many duplicates there are in the dataset and save this number to a variable named `num_dupes`.
# 3. Remove these duplicates from the dataset.

# %% [markdown]
# ### Exercise 1.2 (<font color="red">4 Marks</font>)
#
# Answer the following questions based on the asteroids dataset.
#
#  1. What is the average diameter of a hazardous asteroid in meters? Save this to a variable named `asteroid_size`.
#  2. What percentage of hazardous asteroids have a miss distance of less than 10 million kilometers? Save this to a variable named `percent_near_misses`.

# %% [markdown]
# ### Exercise 1.3 (<font color="red">4 Marks</font>)
#
# 1. Separate the data into potential features and the target variable. Assign these variables to `X` and `y`, respectively.
#
# **NOTE: Remember your goal is to predict whether or not a near-Earth asteroid is <font color="red">hazardous</font>.**
#
# 2. Split the data into training and testing datasets with the names `X_train`, `y_train`, `X_test`, and `y_test`. The training dataset should comprise 80% of the original dataset. Ensure that you use `random_state = 42` for reproducibility.

# %% [markdown]
# ## Section 2. Exploratory Data Analysis (EDA) and Data Preprocessing (<font color="red">18 Marks total</font>)
#
# NASA wants you to use this notebook to do some **Exploratory Data Analysis**. Use a Markdown cell any time you are asked/want to explain your reasonining.
#
# ### Exercise 2.1 (<font color="red">10 Marks</font>)
#
# 1. Check the training set for features with outliers. Do you think these are real outliers (i.e., real data that just so happens to be excessively large or small) or invalid data (measurement errors, NaNs, etc.)? Explain your answer.
#
# 2. If you think there are values that are indicative of invalid data, replace these values with `np.nan` in both the training and testing sets. If not, simply state that no values were replaced.
#
# 3. Inspect the features of your training set. Use your domain knowledge (and common sense) to identify any unimportant features, i.e., features that would not be helpful for predicting whether an asteroid is <font color="red">hazardous</font>. Explain your reasoning.
#
# 4. After identifying the features you want to drop, write a function named `remove_features`and use this function to remove these features from the `X_train` and `X_test` datasets, assigning the results to `X_train_prep` and `X_test_prep`, respectively.
#
# 5. If there are still string features in your `X_train_prep` and `X_test_prep` datasets, use a `LabelEncoder` to convert these to integer features.

# %% [markdown]
# ### Exercise 2.2 (<font color="red">2 Marks</font>)
#
# 1. Use the `.value_counts()` method or plot a histogram to visualize the distribution of classes in your target variable `y_train`. This will give you insight into whether your dataset is *balanced* or *imbalanced*. Briefly describe your results.

# %% [markdown]
# ### Exercise 2.3 (<font color="red">6 Marks</font>)
#
# 1. Check the training set for missing data. Which column(s) have missing data and what strategy would you use to deal with these missing values?
# 2. Create a workflow that both imputes missing values and scales your data.

# %% [markdown]
# ## Section 3. Predicting Hazardous Asteroids (<font color="red">22 Marks total</font>)
#
# In this section, you will develop a model to predict whether asteroids are <font color="red">hazardous</font> based on their features. This task is crucial for NASA  initiatives and helps them prepare for potential asteroid impacts.
#
# ### Exercise 3.1 (<font color="red">4 Marks</font>)
#
# NASA wants you to use a **LogisticRegression** model for this classification task (don't use any fancy RandomForest, KNN or SVM models for this: NASA is too old school for that).
#
# Instantiate an appropriate machine learning model according to NASA's requirements (feel free to add this to any existing pipelines).
#
# **NOTE**: You may wish to consider addressing potential class imbalance: if you noticed that the target variable was imbalanced in Exercise 2.2, consider using the `class_weight` argument for your LogisticRegression model ([look at the scikit-learn documention for the potential values this argument can have](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)). This argument helps the model pay more attention to under-represented classes, which can be crucial for predicting rare but important events, like hazardous asteroids.

# %% [markdown]
# ### Exercise 3.2 (<font color="red">10 Marks</font>)
#
# NASA prioritizes identifying hazardous asteroids accurately, even at the cost of false positives. This means your model should maximize the detection of hazardous asteroids, without worrying too much about incorrectly labeling non-hazardous asteroids as hazardous.
#
# 1. Select a metric based on NASA's requirements. Metrics that you can choose include `accuracy`, `recall`, `precision`, or `f1`.
#
# 2. Tune your model to find the best hyperparameters. **Limit yourself to tuning at most three hyperparameters to save time.** Remember to set `random_state = 42` for reproducibility.
#
# 3. Assign the best model you find to a variable named `best_model`.

# %% [markdown]
# ### Exercise 3.3 (<font color="red">8 Marks</font>)
#
# Evaluate your best model's performance using `X_test_prep`. Use the same metric you chose for hyperparameter tuning.
#
# 1. Save this result to a variable named `best_score`.
# 2. Present the results of your model using an appropriate visualization tool.
# 3. What proportion of the <font color="red">hazardous</font> asteroids predicted by your model were **actually <font color="red">hazardous</font>**?
